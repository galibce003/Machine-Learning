# %% [markdown]
# # Multiple Linear Regression Model with categorical variables
# ### Author : MD. Mehedi Hassan Galib
# ### Date : 02 August, 2020
# <br/>
# <br/>

# %% [markdown]
# ## Loading necessary libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# <br/>
#
# ## Loading dataset

# %%
df = pd.read_csv('C:/Users/Mehedi Hassan Galib/Desktop/Python/datas/car.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# <br/>
#
# ## Categorical variable to Dummy variabnle

# %%
df2 = pd.get_dummies(df, columns = ['Transmission','Fuel_Type'], drop_first = True)
df2
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Seller_Type  \
# 0       ritz  2014           3.35           5.59       27000      Dealer
# 1        sx4  2013           4.75           9.54       43000      Dealer
# 2       ciaz  2017           7.25           9.85        6900      Dealer
# 3    wagon r  2011           2.85           4.15        5200      Dealer
# 4      swift  2014           4.60           6.87       42450      Dealer
# ..       ...   ...            ...            ...         ...         ...
# 296     city  2016           9.50          11.60       33988      Dealer
# 297     brio  2015           4.00           5.90       60000      Dealer
# 298     city  2009           3.35          11.00       87934      Dealer
# 299     city  2017          11.50          12.50        9000      Dealer
# 300     brio  2016           5.30           5.90        5464      Dealer
#
#      Owner  Transmission_Manual  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0        0                    1                 0                 1
# 1        0                    1                 1                 0
# 2        0                    1                 0                 1
# 3        0                    1                 0                 1
# 4        0                    1                 1                 0
# ..     ...                  ...               ...               ...
# 296      0                    1                 1                 0
# 297      0                    1                 0                 1
# 298      0                    1                 0                 1
# 299      0                    1                 1                 0
# 300      0                    1                 0                 1
#
# [301 rows x 10 columns]

# %% [markdown]
# <br/>
#
# ## Observing the relationship between variables

# %%
df2.corr()
# Out:
#                          Year  Selling_Price  Present_Price  Kms_Driven  \
# Year                 1.000000       0.236141      -0.047584   -0.524342
# Selling_Price        0.236141       1.000000       0.878983    0.029187
# Present_Price       -0.047584       0.878983       1.000000    0.203647
# Kms_Driven          -0.524342       0.029187       0.203647    1.000000
# Owner               -0.182104      -0.088344       0.008057    0.089216
# Transmission_Manual  0.000394      -0.367128      -0.348715   -0.162510
# Fuel_Type_Diesel     0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol    -0.059959      -0.540571      -0.465244   -0.172874
#
#                         Owner  Transmission_Manual  Fuel_Type_Diesel  \
# Year                -0.182104             0.000394          0.064315
# Selling_Price       -0.088344            -0.367128          0.552339
# Present_Price        0.008057            -0.348715          0.473306
# Kms_Driven           0.089216            -0.162510          0.172515
# Owner                1.000000            -0.050316         -0.053469
# Transmission_Manual -0.050316             1.000000         -0.098643
# Fuel_Type_Diesel    -0.053469            -0.098643          1.000000
# Fuel_Type_Petrol     0.055687             0.091013         -0.979648
#
#                      Fuel_Type_Petrol
# Year                        -0.059959
# Selling_Price               -0.540571
# Present_Price               -0.465244
# Kms_Driven                  -0.172874
# Owner                        0.055687
# Transmission_Manual          0.091013
# Fuel_Type_Diesel            -0.979648
# Fuel_Type_Petrol             1.000000

# %% [markdown]
# <br/>
#
# ## Splitting Explanatory and Response variable

# %%
X = pd.DataFrame(df2[['Present_Price','Transmission_Manual','Fuel_Type_Diesel','Fuel_Type_Petrol']])
y = pd.DataFrame(df2.Selling_Price)

# %% [markdown]
# <br/>
#
# ## Splitting Train & Test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = .2, random_state = 5)

# %% [markdown]
# <br/>
#
# ## Model build up

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %% [markdown]
# <br/>
#
# ## R-Squared value

# %%
lm.score(X_train, y_train)
# Out:
# 0.7973657496540842

# %% [markdown]
# <br/>
#
# ## Prediction

# %%
y_pred = lm.predict(X_test)
y_pred
# Out:
# array([[12.32919552],
#        [12.32919552],
#        [ 3.78724227],
#        [ 6.59789122],
#        [ 2.63206109],
#        [ 9.45239297],
#        [ 6.7309472 ],
#        [ 1.05316481],
#        [17.6099969 ],
#        [ 3.2074216 ],
#        [ 6.80305854],
#        [ 4.5454693 ],
#        [ 3.36352717],
#        [ 9.21154439],
#        [ 1.08884608],
#        [ 2.64098141],
#        [ 8.96548685],
#        [ 1.13344767],
#        [ 8.96548685],
#        [ 0.91043972],
#        [ 8.96548685],
#        [17.6099969 ],
#        [19.99618196],
#        [ 1.32077435],
#        [ 3.85414465],
#        [ 3.90766656],
#        [ 4.0994534 ],
#        [ 4.85768043],
#        [ 4.10391356],
#        [ 6.79338943],
#        [ 3.2074216 ],
#        [ 6.7309472 ],
#        [ 4.45623926],
#        [ 0.95504131],
#        [ 0.98626243],
#        [ 7.40071984],
#        [ 5.55789853],
#        [ 3.21188176],
#        [ 1.51256119],
#        [ 2.20388583],
#        [ 1.08884608],
#        [ 3.25202319],
#        [11.73967888],
#        [ 1.6463391 ],
#        [ 1.32077435],
#        [ 3.84522434],
#        [ 0.91936004],
#        [ 7.40071984],
#        [ 2.64098141],
#        [ 4.85768043],
#        [ 3.95670145],
#        [15.28179391],
#        [ 4.22433785],
#        [ 1.51256119],
#        [ 1.6463391 ],
#        [ 0.91936004],
#        [ 2.89075031],
#        [ 0.87921861],
#        [ 1.01614549],
#        [ 1.0219437 ],
#        [ 1.03354011]])

# %% [markdown]
# <br/>
#
# ## Prediction of a single data point

# %%
lm.predict([[5.59,1,0,1]])[0][0].round(2)
# Out:
# 3.16
